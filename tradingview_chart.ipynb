# %% [markdown]
# <a href="https://colab.research.google.com/github/neroblack4life/Google-Colab-Projects/blob/main/tradingview_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/filipemarques87/tradingview-chart-py.git
# Out:
# Cloning into 'tradingview-chart-py'...
# remote: Enumerating objects: 81, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 81 (delta 37), reused 58 (delta 22), pack-reused 7 (from 1)
# Receiving objects: 100% (81/81), 158.97 KiB | 4.08 MiB/s, done.
# Resolving deltas: 100% (37/37), done.

# %%
# !cd tradingview-chart-py

# %%
cd tradingview-chart-py/
# Out:
# /content/tradingview-chart-py

# %%
ls -lart
# Out:
# total 156
# drwxr-xr-x 1 root root  4096 Apr  8 12:09 ../
# drwxr-xr-x 2 root root  4096 Apr  8 12:09 .vscode/
# -rw-r--r-- 1 root root  1072 Apr  8 12:09 LICENSE
# -rw-r--r-- 1 root root  1799 Apr  8 12:09 .gitignore
# -rw-r--r-- 1 root root   596 Apr  8 12:09 README.md
# -rw-r--r-- 1 root root 24997 Apr  8 12:09 data.csv
# drwxr-xr-x 3 root root  4096 Apr  8 12:09 pytvchart/
# -rw-r--r-- 1 root root 86522 Apr  8 12:09 figure-1.png
# -rw-r--r-- 1 root root  1497 Apr  8 12:09 test.py
# -rw-r--r-- 1 root root   256 Apr  8 12:09 setup.py
# drwxr-xr-x 8 root root  4096 Apr  8 12:09 .git/
# drwxr-xr-x 5 root root  4096 Apr  8 12:09 ./

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/tradingview-chart-py
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.5/475.5 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 4.4 MB/s eta 0:00:00
# ...
#   Created wheel for proxy_tools: filename=proxy_tools-0.1.0-py3-none-any.whl size=2901 sha256=61c70a032829322c53c6494af0a6c2b9e84338e06c36b96b8554d911b7a8d9e9
#   Stored in directory: /root/.cache/pip/wheels/2b/5f/96/7e96e7cbf06e426e168a6891a6ca2226787cc79fc816830dd4
# Successfully built proxy_tools
# ...
#   Running setup.py develop for pytvchart
# ...

# %%
# !pip install qtpy PyQt5
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.0/95.0 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 36.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 MB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.4/276.4 kB 16.5 MB/s eta 0:00:00
# ...

# %%
# !sudo apt-get install python3-gi gir1.2-gtk-3.0 libgtk-3-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3-gi is already the newest version (3.42.1-0ubuntu1).
# python3-gi set to manually installed.
# The following additional packages will be installed:
#   gir1.2-atk-1.0 gir1.2-atspi-2.0 libatk-bridge2.0-dev libatk1.0-dev
#   libatspi2.0-dev libdatrie-dev libdbus-1-dev libegl-dev libegl1-mesa-dev
#   libepoxy-dev libfribidi-dev libgdk-pixbuf-2.0-dev libgdk-pixbuf2.0-bin
#   libgl-dev libgles-dev libgles1 libglvnd-core-dev libglvnd-dev libglx-dev
#   libgraphite2-dev libharfbuzz-dev libharfbuzz-gobject0 libharfbuzz-icu0
#   libopengl-dev libpango1.0-dev libthai-dev libwayland-bin libwayland-dev
#   libxcomposite-dev libxcursor-dev libxdamage-dev libxfixes-dev libxi-dev
#   libxinerama-dev libxkbcommon-dev libxrandr-dev libxtst-dev libxtst6
#   pango1.0-tools wayland-protocols
# Suggested packages:
#   libdatrie-doc libgraphite2-utils libgtk-3-doc libpango1.0-doc libthai-doc
# ...

# %%
# !sudo apt-get install gir1.2-webkit2-4.0
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libfuse2
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   aspell aspell-en bubblewrap dictionaries-common enchant-2 fuse3
#   gir1.2-javascriptcoregtk-4.0 gir1.2-soup-2.4 glib-networking
#   glib-networking-common glib-networking-services gsettings-desktop-schemas
#   gstreamer1.0-gl gstreamer1.0-plugins-base gstreamer1.0-plugins-good
#   gstreamer1.0-x hunspell-en-us libaa1 libaspell15 libcanberra0 libcdparanoia0
#   libdv4 libenchant-2-2 libevdev2 libfuse3-3 libgstreamer-gl1.0-0
#   libgstreamer-plugins-good1.0-0 libgudev-1.0-0 libhunspell-1.7-0 libhyphen0
#   libjavascriptcoregtk-4.0-18 libjson-glib-1.0-0 libjson-glib-1.0-common
#   libmanette-0.2-0 libpipewire-0.3-0 libpipewire-0.3-common
# ...

# %%
# !pip install PyQtWebEngine
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 MB 6.9 MB/s eta 0:00:00
# ...

# %%
# !python3 -c "import gi; gi.require_version('Gtk', '3.0'); print('GTK OK')"
# Out:
# GTK OK

# %%
# !export QT_DEBUG_PLUGINS=1

# %%
# !pip uninstall pywebview -y && pip install pywebview[gtk]
# Out:
# Found existing installation: pywebview 5.4
# Uninstalling pywebview-5.4:
#   Successfully uninstalled pywebview-5.4
# ...
#   Using cached pywebview-5.4-py3-none-any.whl.metadata (4.5 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 870.2/870.2 kB 11.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# Using cached pywebview-5.4-py3-none-any.whl (475 kB)
# ...
#   Created wheel for PyGObject-stubs: filename=pygobject_stubs-2.13.0-py3-none-any.whl size=1084569 sha256=75e2676b4524ec886bc729e78859f1e6dea2a27b6b83bcbaa985d7a10f543954
#   Stored in directory: /root/.cache/pip/wheels/b9/d4/10/06393208ab794807e7d9bd3b75e1a39c2d87cb14681372e817
# Successfully built PyGObject-stubs
# ...

# %%
# !sudo apt-get install python3-gi gir1.2-gtk-3.0 libgtk-3-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# gir1.2-gtk-3.0 is already the newest version (3.24.33-1ubuntu2.2).
# libgtk-3-dev is already the newest version (3.24.33-1ubuntu2.2).
# python3-gi is already the newest version (3.42.1-0ubuntu1).
# The following package was automatically installed and is no longer required:
#   libfuse2
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 30 not upgraded.

# %%
# !sudo apt-get install qt5-default libqt5webenginewidgets5
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Package qt5-default is not available, but is referred to by another package.
# This may mean that the package is missing, has been obsoleted, or
# is only available from another source
#
# E: Package 'qt5-default' has no installation candidate

# %%
# !export PYWEBVIEW_GUI=gtk

# %%
# !export QT_QPA_PLATFORM=xcb   &&  export QT_QPA_PLATFORM=xcb

# %%
# !python test.py
# Out:
# [pywebview] WebKit2 4.1 not found. Using 4.0.
# [pywebview] Using GTK
# [pywebview] HTTP server root path: /content/tradingview-chart-py/pytvchart/web
# Bottle v0.13.2 server starting up (using ThreadedAdapter())...
# Listening on http://127.0.0.1:14215/
# Hit Ctrl-C to quit.
#
#
# (test.py:10849): Gtk-WARNING **: 12:31:17.205: cannot open display:

# %%
# !ls -lart
# Out:
# total 16
# drwxr-xr-x 4 root root 4096 Apr  4 13:37 .config/
# drwxr-xr-x 1 root root 4096 Apr  4 13:38 ./
# drwxr-xr-x 1 root root 4096 Apr  4 13:38 sample_data/
# drwxr-xr-x 1 root root 4096 Apr  8 11:54 ../

# %%
# !python3 test.py
# Out:
# [pywebview] GTK cannot be loaded
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pywebview-5.4-py3.11.egg/webview/guilib.py", line 37, in import_gtk
#     import webview.platforms.gtk as guilib
#   File "/usr/local/lib/python3.11/dist-packages/pywebview-5.4-py3.11.egg/webview/platforms/gtk.py", line 22, in <module>
#     gi.require_version('Gtk', '3.0')
#   File "/usr/local/lib/python3.11/dist-packages/gi/__init__.py", line 129, in require_version
#     raise ValueError('Namespace %s not available for version %s' %
# ValueError: Namespace Gtk not available for version 3.0
# [pywebview] QT cannot be loaded
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pywebview-5.4-py3.11.egg/webview/guilib.py", line 49, in import_qt
#     import webview.platforms.qt as guilib
#   File "/usr/local/lib/python3.11/dist-packages/pywebview-5.4-py3.11.egg/webview/platforms/qt.py", line 23, in <module>
# ...
